# %% [markdown]
# # **LSTM Forecast - Reservoir Levels**
#
#
# ---

# %% [markdown]
# ## **Libraries**

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
import math

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, Embedding, LSTM, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.backend import square, mean

# %% [markdown]
# ## **Load Data**
#
# The data was obtained from 2 sources:
# 1.   Watercare Services Limited
# 2.   NIWA

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_UN= pd.read_csv('gdrive/My Drive/DL Project/Upper Niho/Upper_Niho_Clean.csv', index_col=0, parse_dates=['Date'], dayfirst=True)#, squeeze=True
df_M= pd.read_csv('gdrive/My Drive/DL Project/Mangatangi/Mangatangi_All.csv', index_col=0, parse_dates=['Date'], dayfirst=True)#, squeeze=True
df_W= pd.read_csv('gdrive/My Drive/DL Project/Waitakere/Waitakere_Clean.csv', index_col=0, parse_dates=['Date'], dayfirst=True)#, squeeze=True

# %%
df_orig = df_M #select site

# %%
if df_orig is df_UN:
  site = 'Upper Nihotupu'
elif df_orig is df_M:
  site = 'Mangatangi'
elif df_orig is df_W:
  site = 'Waitakere'

# %%
#shift_steps = 7

# %%
model_type = 'GRU'

# %%
#df= pd.read_csv('gdrive/My Drive/DL Project/Mangatangi/Mangatangi_All.csv', index_col=0, parse_dates=['Date'], dayfirst=True)#, squeeze=True
#df_orig = pd.read_csv('gdrive/My Drive/DL Project/Upper Niho/Upper_Niho_Clean.csv', index_col=0, parse_dates=['Date'], dayfirst=True)#, squeeze=True

# %%
#df_orig.drop(['Rainfall (NIWA)' ], axis=1, inplace=True)#, 'Vapour Pressure (hPa)', 'Max Temp'

# %%
df_val = df_orig[-365:]

# %%
y_val = df_val['Level']

# %%
df = df_orig[:-(365)]

# %%
print(len(df_val))
print(len(df_orig))
print(len(y_val))
# Out:
# 365
# 4464
# 365

# %% [markdown]
# Interpolating to handle missing values:

# %%
df.values.shape
# Out:
# (4099, 13)

# %% [markdown]
# ### **Target**
#
# The output we want to predict

# %%
target = ['Level']

# %% [markdown]
# Shifting the target column to the number of steps ahead we want to forecast

# %%
df_targets = df[target]

# %%
df_targets.head()
# Out:
#              Level
# Date
# 2009-01-01  52.137
# 2009-01-02  52.094
# 2009-01-03  52.057
# 2009-01-04  52.013
# 2009-01-05  51.958

# %%
df.drop(['Level'], axis=1, inplace=True)
df_val.drop(['Level'], axis=1, inplace=True)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### **NumPy Array**
#
#
#
# 1.   Converting to NumPy array to feed into the neural network.
# 2.   Removing the 'NaN' values due to the shift.
# 3.   Train/test split

# %% [markdown]
# Input data

# %%
x_data = df.values[0:]

# %%
x_data.shape
# Out:
# (4099, 12)

# %%
print(type(x_data))
print("Shape:", x_data.shape)
# Out:
# <class 'numpy.ndarray'>
# Shape: (4099, 12)

# %% [markdown]
# Output data

# %%
y_data = df_targets.values[:]

# %%
print(type(y_data))
print("Shape:", y_data.shape)
# Out:
# <class 'numpy.ndarray'>
# Shape: (4099, 1)

# %% [markdown]
# Number of observations/rows in the dataset

# %%
num_data = len(x_data)
num_data
# Out:
# 4099

# %% [markdown]
# Train/test fraction

# %%
train_split = 0.85

# %% [markdown]
# Number of training and testing samples

# %%
num_train = int(train_split * num_data)
num_test = num_data - num_train

print (f'Number of training samples: {num_train}')
print (f'Number of test samples: {num_test}')
# Out:
# Number of training samples: 3484
# Number of test samples: 615

# %% [markdown]
# Input-signals for the training- and test-sets:

# %%
x_train = x_data[0:num_train]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 4099

# %%
x_train.shape
# Out:
# (3484, 12)

# %% [markdown]
# Output-signals for the training- and test-sets:

# %%
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
len(y_train) + len(y_test)
# Out:
# 4099

# %% [markdown]
# Number of input features

# %%
num_x_signals = x_data.shape[1]
num_x_signals
# Out:
# 12

# %% [markdown]
# Number of output signals

# %%
num_y_signals = y_data.shape[1]
num_y_signals
# Out:
# 1

# %% [markdown]
# ### **Data Scaling**

# %% [markdown]
# Range of values from the dataset

# %%
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: -142.0
# Max: 135859.625

# %%
print("Min:", np.min(y_train))
print("Max:", np.max(y_train))
# Out:
# Min: 42.291000000000004
# Max: 55.051

# %% [markdown]
# Creating a scaler object for the inputs

# %%
x_scaler = MinMaxScaler() #scaling data between 0 & 1

# %% [markdown]
# Scaling the training input data

# %%
x_train_scaled = x_scaler.fit_transform(x_train)

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: 0.0
# Max: 1.0

# %% [markdown]
# Scaling the testing input data

# %%
x_test_scaled = x_scaler.transform(x_test)

# %% [markdown]
# Scaling the output/target data. Note a separate scaling object (y_scaler) is created.

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %% [markdown]
# ## **Data Generator**

# %% [markdown]
# The data has now been prepared as 2D NumPy arrays.

# %%
print(f'X Train Shape: {x_train_scaled.shape}')
print(f'Y Train Shape: {y_train_scaled.shape}')
# Out:
# X Train Shape: (3484, 12)
# Y Train Shape: (3484, 1)

# %%
print(f'X Val Shape: {x_test_scaled.shape}')
print(f'Y Val Shape: {y_test_scaled.shape}')
# Out:
# X Val Shape: (615, 12)
# Y Val Shape: (615, 1)

# %% [markdown]
# A batch_generator function is used to create a batch of shorter sub-sequences picked at random from the training-data.

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %% [markdown]
# Defining batch size

# %%
batch_size = 10

# %% [markdown]
# Defining sequence length. Number of observations per batch

# %%
sequence_length = 100

# %% [markdown]
# Assigning generator function

# %%
generator = batch_generator(batch_size=batch_size,
                            sequence_length=sequence_length)

# %% [markdown]
# Testing the batch-generator

# %%
x_batch, y_batch = next(generator)

# %%
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (10, 100, 12)
# (10, 100, 1)

# %%
batch = 0   # First sequence in the batch.
signal = 0  # First signal from the 13 input-signals.
seq = x_batch[batch, :, signal]
plt.plot(seq)

# %%
seq = y_batch[batch, :, signal]
plt.plot(seq)

# %% [markdown]
# ### **Validation Set**
#
# To overcome the risk of overfitting, the performance is monitored on the test set after each epoch and the models weights are saved only if the performance is improved on the test set.

# %% [markdown]
# The batch-generator randomly selects a batch of short sequences from the training-data and uses that during training. But for the validation-data we will instead run through the entire sequence from the test-set and measure the prediction accuracy on that entire sequence.

# %%
validation_data = (np.expand_dims(x_test_scaled, axis=0),
                   np.expand_dims(y_test_scaled, axis=0))

# %%
re, er = validation_data

# %%
re.shape
# Out:
# (1, 615, 12)

# %%
er.shape
# Out:
# (1, 615, 1)

# %% [markdown]
# ## **Gated Recurrent Unit (GRU)**

# %% [markdown]
# Recurrent Neural Network (RNN) is created using the Keras API.
#
# **1st Hidden layer:**
#
# The GRU will have 512 outputs for each time-step in the sequence.
#
# Note that because this is the first layer in the model, Keras needs to know the shape of its input, which is a batch of sequences of arbitrary length (indicated by None), where each observation has a number of input-signals (num_x_signals).
#
# **Dense layer:**
#
# A fully-connected (or dense) layer is then added which maps 512 values down to only 1 value.
#
# **Activation Function:**
#
# A linear activation function is used on the output so that the output values can take on arbitary values and, unlike a sigmoid activation function, which maps outputs between 0 and 1, the linear activation output is not constrained by the values of the training data.

# %%
from tensorflow.python.keras.initializers import RandomUniform

init = RandomUniform(minval=-0.05, maxval=0.05)

# %%
model = Sequential()
if model_type == 'LSTM':
  model.add(LSTM(512,return_sequences=True, dropout=0.1,input_shape=(None, num_x_signals)))

elif model_type == 'GRU':
  model.add(GRU(units=512,
            return_sequences=True,
            dropout=0.2,
            input_shape=(None, num_x_signals)))

model.add(Dense(num_y_signals, 
                kernel_initializer=init))
                #activation='linear',
#            dropout=0.2,

# %%
#from tensorflow.python.keras.initializers import RandomUniform

#init = RandomUniform(minval=-0.05, maxval=0.05)

#model.add(Dense(num_y_signals, 
                #activation='linear',
                #kernel_initializer=init))
#if False:
  #from tensorflow.python.keras.initializers import RandomUniform

    # Maybe use lower init-ranges.
    #init = RandomUniform(minval=-0.05, maxval=0.05)

    #model.add(Dense(num_y_signals,
                    #activation='linear',
                    #kernel_initializer=init))

# %% [markdown]
# ### **Loss Function**

# %% [markdown]
# We will use Mean Squared Error (MSE) as the loss-function that will be minimized. This measures how closely the model's output matches the true output signals.
#
# However, at the beginning of a sequence, the model has only seen input-signals for a few time-steps, so its generated output may be very inaccurate. Using the loss-value for the early time-steps may cause the model to distort its later output. We therefore give the model a "warmup-period" of 50 time-steps where we don't use its accuracy in the loss-function, in hope of improving the accuracy for later time-steps.

# %%
warmup_steps = 50

# %%
# def loss_mse_warmup(y_true, y_pred):
#     """
#     Calculate the Mean Squared Error between y_true and y_pred,
#     but ignore the beginning "warmup" part of the sequences.
    
#     y_true is the desired output.
#     y_pred is the model's output.
#     """

#     # The shape of both input tensors are:
#     # [batch_size, sequence_length, num_y_signals].

#     # Ignore the "warmup" parts of the sequences
#     # by taking slices of the tensors.
#     y_true_slice = y_true[:, warmup_steps:, :]
#     y_pred_slice = y_pred[:, warmup_steps:, :]

#     # These sliced tensors both have this shape:
#     # [batch_size, sequence_length - warmup_steps, num_y_signals]

#     # Calculate the Mean Squared Error and use it as loss.
#     mse = mean(square(y_true_slice - y_pred_slice))
    
#     return mse

# %% [markdown]
# ### **Compile Model**

# %% [markdown]
# Optimizer

# %%
#optimizer = RMSprop(lr=1e-3)
optimizer = Adam(lr=1e-3)

# %% [markdown]
# Compile the Keras model so it is ready for training.

# %%
#model.compile(loss=loss_mse_warmup, optimizer=optimizer)
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_3 (GRU)                  (None, None, 512)         807936
# _________________________________________________________________
# dense_3 (Dense)              (None, None, 1)           513
# =================================================================
# Total params: 808,449
# Trainable params: 808,449
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Callback Functions**
#
# During training we want to save checkpoints and log the progress to TensorBoard so we create the appropriate callbacks for Keras.

# %% [markdown]
# This is the callback for writing checkpoints during training.

# %%
path_checkpoint = '23_checkpoint.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %% [markdown]
# This is the callback for stopping the optimization when performance worsens on the validation-set.

# %%
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=15, verbose=1)

# %% [markdown]
# This is the callback for writing the TensorBoard log during training.

# %%
callback_tensorboard = TensorBoard(log_dir='./23_logs/',
                                   histogram_freq=1,
                                   write_graph=True)

# %% [markdown]
# This callback reduces the learning-rate for the optimizer if the validation-loss has not improved since the last epoch (as indicated by patience=0). The learning-rate will be reduced by multiplying it with the given factor. We set a start learning-rate of 1e-3 above, so multiplying it by 0.1 gives a learning-rate of 1e-4. We don't want the learning-rate to go any lower than this.

# %%
callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

# %%
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr]

# %% [markdown]
# ## **Training the Recurrent Neural Network**

# %% [markdown]
# We can now train the neural network.
#
# Note that a single "epoch" does not correspond to a single processing of the training-set, because of how the batch-generator randomly selects sub-sequences from the training-set. Instead we have selected steps_per_epoch

# %%
# %%time
validation = model.fit(x=generator,
          epochs=100,
          steps_per_epoch=30,
          validation_data=validation_data,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 3s 49ms/step - loss: 0.0623 - val_loss: 0.0129
#
# Epoch 00001: val_loss improved from inf to 0.01286, saving model to 23_checkpoint.keras
# Epoch 2/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0212 - val_loss: 0.0142
#
# Epoch 00002: val_loss did not improve from 0.01286
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 3/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0182 - val_loss: 0.0155
#
# Epoch 00003: val_loss did not improve from 0.01286
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 4/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0178 - val_loss: 0.0167
#
# Epoch 00004: val_loss did not improve from 0.01286
# Epoch 5/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0173 - val_loss: 0.0140
#
# Epoch 00005: val_loss did not improve from 0.01286
# Epoch 6/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0185 - val_loss: 0.0182
#
# Epoch 00006: val_loss did not improve from 0.01286
# Epoch 7/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0153 - val_loss: 0.0145
#
# Epoch 00007: val_loss did not improve from 0.01286
# Epoch 8/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0183 - val_loss: 0.0160
#
# Epoch 00008: val_loss did not improve from 0.01286
# Epoch 9/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0160 - val_loss: 0.0182
#
# Epoch 00009: val_loss did not improve from 0.01286
# Epoch 10/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0163 - val_loss: 0.0220
#
# Epoch 00010: val_loss did not improve from 0.01286
# Epoch 11/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0145 - val_loss: 0.0207
#
# Epoch 00011: val_loss did not improve from 0.01286
# Epoch 12/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0164 - val_loss: 0.0246
#
# Epoch 00012: val_loss did not improve from 0.01286
# Epoch 13/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0132 - val_loss: 0.0382
#
# Epoch 00013: val_loss did not improve from 0.01286
# Epoch 14/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0164 - val_loss: 0.0455
#
# Epoch 00014: val_loss did not improve from 0.01286
# Epoch 15/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0156 - val_loss: 0.0170
#
# Epoch 00015: val_loss did not improve from 0.01286
# Epoch 16/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0154 - val_loss: 0.0242
#
# Epoch 00016: val_loss did not improve from 0.01286
# Epoch 00016: early stopping
# CPU times: user 9.56 s, sys: 450 ms, total: 10 s
# Wall time: 9.18 s

# %% [markdown]
# **Load Checkpoint**
#
# Because early-stopping was used when training the model, it is possible that the model's performance has worsened on the test-set for several epochs before training was stopped. We therefore reload the last saved checkpoint, which should have the best performance on the test-set.

# %%
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %% [markdown]
# ### **Model Performance on Test Set**

# %%
plt.plot(validation.history['val_loss'], 'r', validation.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f'{site} - + Training Loss ({model_type})')
plt.legend(['val loss','train loss'])

# %%
result = model.evaluate(x=np.expand_dims(x_test_scaled, axis=0),
                        y=np.expand_dims(y_test_scaled, axis=0))
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0129

# %%
print("loss (test-set):", result)
# Out:
# loss (test-set): 0.012856497429311275

# %%
# If you have several metrics you can use this instead.
if False:
    for res, metric in zip(result, model.metrics_names):
        print("{0}: {1:.3e}".format(metric, res))

# %% [markdown]
# ---

# %% [markdown]
# ## **Results**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
x = x_test_scaled
y_true = y_test

# %%
start_idx = 0
length = 3000

# %%
end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
x = x[start_idx:end_idx]
y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7cde982cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for signal in range(len(target)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:, signal]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:, signal]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(15,5))
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')

        result_table = pd.DataFrame(signal_true)
        result_table['pred'] = pd.DataFrame(signal_pred)
    
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)

        #MAE and MSE
        mae = mean_absolute_error(signal_true[10:],signal_pred[10:])
        mse = mean_squared_error(signal_true[10:],signal_pred[10:])
        rmse = math.sqrt(mean_squared_error(signal_true[10:], signal_pred[10:]))
        
        # Plot labels etc.
        plt.xlabel("Timestep (Day)")
        plt.ylabel("Level (m)")
        plt.title(f'{site} - Performance on Validation Set ({model_type}-No Level)')
        #plt.ylabel(target[signal])
        plt.legend()
        plt.show()

# %% [markdown]
# ### **Plotting Entire Dataset (Train, Test and Predictions)**

# %%
x1 = x_train_scaled
y_true1 = y_train

# %%
# For each output-signal.
for signal in range(len(target)):
    # Get the output-signal predicted by the model.
    signal_pred = y_pred_rescaled[:, signal]
    
    # Get the true output-signal from the data-set.
    signal_true = y_true1[:, signal]

    # Make the plotting-canvas bigger.
    plt.figure(figsize=(25,10))
    
    # Plot and compare the two signals.
    plt.ylabel(target[signal])
    plt.legend()
    plt.plot(y_data, label='true')
    plt.plot([None for x in y_true1] + [x for x in signal_pred], label='pred')
    plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### **Evaluating forecast accuracy**

# %% [markdown]
# Two calculations related to linear regression are <a href='https://en.wikipedia.org/wiki/Mean_squared_error'><strong>mean squared error</strong></a> (MSE) and <a href='https://en.wikipedia.org/wiki/Root-mean-square_deviation'><strong>root mean squared error</strong></a> (RMSE)
#
# The formula for the mean squared error is<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;$MSE = {\frac 1 L} \sum\limits_{l=1}^L (y_{T+l} - \hat y_{T+l})^2$<br><br>
# where $T$ is the last observation period and $l$ is the lag point up to $L$ number of test observations.
#
# The formula for the root mean squared error is<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;$RMSE = \sqrt{MSE} = \sqrt{{\frac 1 L} \sum\limits_{l=1}^L (y_{T+l} - \hat y_{T+l})^2}$<br><br>
#
# The advantage of the RMSE is that it is expressed in the same units as the data.<br><br>
#
# A method similar to the RMSE is the <a href='https://en.wikipedia.org/wiki/Mean_absolute_error'><strong>mean absolute error</strong></a> (MAE) which is the mean of the magnitudes of the error, given as<br><br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;$MAE = {\frac 1 L} \sum\limits_{l=1}^L \mid{y_{T+l}} - \hat y_{T+l}\mid$<br><br>
#
# A forecast method that minimizes the MAE will lead to forecasts of the median, while minimizing the RMSE will lead to forecasts of the mean.

# %%
print(f'mean absolute error {mae}')
print(f'mean squared error {mse}')
print (f'root mean squared error {rmse}')
# Out:
# mean absolute error 1.5359624866832389
# mean squared error 3.8387580331917732
# root mean squared error 1.9592748743327908

# %% [markdown]
# ---

# %% [markdown]
# # **Saving and Running Model**

# %%
from tensorflow.keras.models import load_model

# %%
model.save(f"{model_type}_{site}_NoLevel.h5")

# %%
#model_2 = load_model(f'/content/LSTM{site}_{shift_steps}Day.h5', compile=False)

# %%
x_test2 = df_val.values

# %%
x_test2_scaled = x_scaler.transform(x_test2)

# %%
x2 = x_test2_scaled    
    # Input-signals for the model.
x2 = np.expand_dims(x2, axis=0)

# %%
x2.shape
# Out:
# (1, 365, 12)

# %%
y_pred2 = model.predict(x2)
#y_pred2 = model.predict(x2)
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7cde982cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
y_pred_rescaled2 = y_scaler.inverse_transform(y_pred2[0])

# %%
result_df = pd.DataFrame(y_val)

# %%
result_df['pred'] = y_pred_rescaled2

# %%
result_df
# Out:
#              Level       pred
# Date
# 2020-03-23  44.634  45.522144
# 2020-03-24  44.559  47.712902
# 2020-03-25  44.479  48.487587
# 2020-03-26  44.394  48.331600
# 2020-03-27  44.311  47.947601
# ...            ...        ...
# 2021-03-18  43.938  46.003143
# 2021-03-19  43.887  45.682022
# 2021-03-20  43.851  45.335674
# 2021-03-21  43.815  45.083019
# 2021-03-22  43.781  44.889633
#
# [365 rows x 2 columns]

# %%
plt.figure(figsize=(15,10))
result_df.plot(y=['Level','pred'])
plt.xlabel("Date")
plt.ylabel("Level (m)")
plt.title(f'{site} - + Performance on Test Set ({model_type}-No Level)')
# Out:
# Text(0.5, 1.0, 'Mangatangi - + Performance on Test Set (GRU-No Level)')

# %%
result_df['year'] = result_df.index.year
result_df['month'] = result_df.index.month

# %%
month_n = 12
df_month = result_df.groupby('month')

# %%
error_df = pd.DataFrame()
rmse_list = []
mse_list = []
mae_list = []
for i in range(1,13):
  rmse_month = math.sqrt(mean_squared_error(df_month.get_group(i)['Level'], df_month.get_group(i)['pred']))
  #mse_month = mean_squared_error(df_month.get_group(i)['Level'], df_month.get_group(i)['pred'])
  mae_month = mean_absolute_error(df_month.get_group(i)['Level'], df_month.get_group(i)['pred'])

  rmse_list.append(rmse_month)
  #mse_list.append(mse_month)
  mae_list.append(mae_month)
  error_df = pd.DataFrame(rmse_list, columns=['RMSE'])
  #error_df['MSE'] = mse_list
  error_df['MAE'] = mae_list

# %%
error_df.set_index([['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']], inplace=True)

# %%
#mse = mean_squared_error(y_val[10:], y_pred_rescaled2[10:])
rmse = math.sqrt(mean_squared_error(y_val[10:], y_pred_rescaled2[10:]))
mae = mean_absolute_error(y_val[10:], y_pred_rescaled2[10:])
#print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
# Out:
# RMSE: 3.012221848851377
# MAE: 2.5148777030837373

# %%
# Plot a bar chart using the DF
ax_errors = error_df.plot(kind="bar")
# Get a Matplotlib figure from the axes object for formatting purposes
fig_errors = ax_errors.get_figure()
# Change the plot dimensions (width, height)
fig_errors.set_size_inches(9, 6)
# Change the axes labels
ax_errors.set_xlabel("Months")
ax_errors.set_ylabel("Error")
plt.title(f'{site} - +Forecast Error Monthly ({model_type}-No Level)')
# Out:
# Text(0.5, 1.0, 'Mangatangi - +Forecast Error Monthly (GRU-No Level)')

# %% [markdown]
# # **Plotting**

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.39.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.41.1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (56.1.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)

# %%
import shap

# %%
from xgboost import XGBClassifier, XGBRegressor

# %%
model_XGB = XGBRegressor(n_estimators=1000, max_depth=10, learning_rate=0.001)# Fit the Model
model_XGB.fit(x_train_scaled, y_train_scaled)
# Out:
# [20:29:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.001, max_delta_step=0,
#              max_depth=10, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
explainer = shap.TreeExplainer(model_XGB)
shap_values = explainer.shap_values(x_train_scaled)

# %%
shap.summary_plot(shap_values, features=x_train_scaled, feature_names=df.columns, plot_type= 'bar', title=' XGBoost SHAP values)')
#plt.title(f'{site} - +Forecast Error Monthly ({model_type}-No Level)')
